# %%
import requests
import csv
 
key = input('Masukkan keyword: ')
write = csv.writer(open('hasil/{}.csv'.format(key), 'w', newline=''))
header = ['Nama', 'Harga', 'Alamat']
write.writerow(header)
 
url = 'https://api.bukalapak.com/multistrategy-products'
count = 0
for page in range(1, 3):
    parameter = {
        'keywords': 'smart watch',
        'limit': 50,
        'offset': 50,
        'facet': True,
        'page': 2,
        'shouldUseSeoMultistrategy': False,
        'isLoggedIn': False,
        'show_search_contexts': True,
        'access_token': 'eyJhbGciOiJSUzI1NiIsImtpZCI6ImFjY291bnRzLmp3dC5hY2Nlc3MtdG9rZW4iLCJ0eXAiOiJKV1QifQ.....GcTXf8O11oPYnrhX4k4bHCCY7wTr10Ly-buE-2mQNb3KzFSMnZ-C9MfhSqd4vQnPD_a8hS6yZd61YCKvBMR3eFdxkLWvv-vqLjd8j_EEqUP-aChjce9jvOzedWwQQmgMjbU8ZkA7aLo6w3KrzTk7c4F5UeHxVSJ63LWDU2OqEiQ4ynrY5zbYzdU2-bpy8dg-agnVnW0g5N107AWcZkLDvgSZ7KOKPCOS6eN4-VEhR_2aei2W4zpjH8pLZjLpuYRORTDcbgjuOfpIQmCWeu-6hroxuxvwVthr32m5y4yiHDWqIb5GvofPCzXF1yffHI71WG-SX3e6L6dTL8JX5QceFQ'

    }
 
    r = requests.get(url, params=parameter).json()
 
    products = r['data']
    for p in products:
        nama = p['name']
        harga = p['price']
        alamat = p['store']['address']['city']
        count += 1
        print('No:', count, 'Nama:', nama, 'Harga:', harga, 'Alamat:', alamat)
        write = csv.writer(open('hasil/{}.csv'.format(key), 'a', newline=''))
        data = [nama, harga, alamat]
        write.writerow(data)
# Out:
# Masukkan keyword: jam
# No: 1 Nama: Smart Watch Hw67 Mini Harga: 440000 Alamat: Jakarta Utara
# No: 2 Nama: smart watch z66 ultra Harga: 440000 Alamat: Jakarta Utara
# No: 3 Nama: smart watch z55 ultra Harga: 440000 Alamat: Jakarta Utara
# No: 4 Nama: smart watch active 2 Harga: 455000 Alamat: Jakarta Utara
# No: 5 Nama: smart watch watch 8 Harga: 455000 Alamat: Jakarta Utara
# No: 6 Nama: Xiaomi Mi Watch Smart AMOLED Garansi Resmi Harga: 1620780 Alamat: Jakarta Pusat
# No: 7 Nama: AMAZFIT GTS BLACK - SMARTWATCH XIAOMI - SMART WATCH HUAMI Harga: 739000 Alamat: Jakarta Selatan
# No: 8 Nama: Smartwatch DT7 MAX Wireless Charging Smart Watch Harga: 685000 Alamat: Jakarta Pusat
# No: 9 Nama: Smart Watch for Android and IOS Smartwatch Harga: 350000 Alamat: Jakarta Barat
# No: 10 Nama: Haylou SOLAR Lite Smart Watch IP68 SpO2 1.38" Display - LS05 Lite Harga: 279000 Alamat: Kab. Tangerang
# ...

# %%
import csv
import matplotlib.pyplot as plt

# Membaca file CSV
data = []
with open('hasil/jam.csv'.format(key), 'r') as file:
    reader = csv.reader(file)
    header = next(reader)  # Membaca baris header
    for row in reader:
        data.append(row)

# Mengambil harga dari data
harga = [float(row[1]) for row in data]

# Membuat histogram
plt.figure(figsize=(10, 6))  # Mengatur ukuran diagram
plt.hist(harga, bins=10, edgecolor='black')  # Jumlah bins disesuaikan dengan preferensi Anda
plt.xlabel('Harga')
plt.ylabel('Frekuensi')
plt.title('Histogram Harga')

# Menyimpan histogram sebagai file gambar
plt.savefig('hasil/histogram.png')

# Menampilkan histogram
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

# Membaca file CSV
data = []
with open('hasil/jam.csv'.format(key), 'r') as file:
    reader = csv.reader(file)
    header = next(reader)  # Membaca baris header
    for row in reader:
        data.append(row)

# Mengambil nomor antri dan harga dari data
nomor_antri = [row[0] for row in data]
harga = [float(row[1]) for row in data]

# Membuat diagram batang
plt.figure(figsize=(10, 6))  # Mengatur ukuran diagram
plt.bar(nomor_antri, harga)
plt.xlabel('Nomor Antri')
plt.ylabel('Harga')
plt.title('Diagram Batang')

# Menyimpan diagram batang sebagai file gambar
plt.savefig('hasil/diagram_batang.png')

# Menampilkan diagram batang
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

# Membaca data dari file CSV
data = []
with open('hasil/jam.csv', 'r') as file:
    reader = csv.reader(file)
    header = next(reader)  # Membaca header
    for row in reader:
        data.append(row)

# Menghitung jumlah produk berdasarkan alamat
alamat_counts = {}
for row in data:
    alamat = row[2]
    if alamat in alamat_counts:
        alamat_counts[alamat] += 1
    else:
        alamat_counts[alamat] = 1

# Persiapan data untuk pie chart
labels = list(alamat_counts.keys())
counts = list(alamat_counts.values())

# Pie Chart
plt.figure(figsize=(8, 6))
plt.pie(counts, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Pie Chart - Persentase alamat ')
plt.show()

# Menyimpan gambar grafik batang dengan latar belakang putih
plt.savefig('hasil/pie_jam.png')

# Menampilkan gambar grafik batang
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

# Membaca data dari file CSV
data = []
with open('hasil/jam.csv', 'r') as file:
    reader = csv.reader(file)
    header = next(reader)  # Membaca header
    for row in reader:
        data.append(row)

# Menyiapkan data yang diperlukan untuk grafik
x = range(1, len(data) + 1)  # Nilai x (misalnya nomor entri)
harga = [float(row[1]) for row in data]  # Nilai harga

# Line Chart
plt.figure(figsize=(8, 6))
plt.plot(harga)
plt.xlabel('Produk')
plt.ylabel('Harga')
plt.title('Line Chart - Harga Produk')
plt.show()


# Menyimpan gambar grafik batang dengan latar belakang putih
plt.savefig('hasil/grafik_line_jam.png')

# Menampilkan gambar grafik batang
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

# Membaca data dari file CSV
data = []
with open('hasil/jam.csv', 'r') as file:
    reader = csv.reader(file)
    header = next(reader)  # Membaca header
    for row in reader:
        data.append(row)

# Menyiapkan data yang diperlukan untuk grafik
x = range(1, len(data) + 1)  # Nilai x (misalnya nomor entri)
harga = [float(row[1]) for row in data]  # Nilai harga


# Scatter Plot
addresses = [row[2] for row in data]
plt.figure(figsize=(8, 6))
plt.scatter(harga, addresses)
plt.xlabel('Harga')
plt.ylabel('Alamat')
plt.title('Scatter Plot - Hubungan Harga dan Alamat Produk')
plt.show()

# Menyimpan gambar grafik batang dengan latar belakang putih
plt.savefig('hasil/scatter_jam.png')

# Menampilkan gambar grafik batang
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

# Membaca data dari file CSV
data = []
with open('hasil/jam.csv', 'r') as file:
    reader = csv.reader(file)
    header = next(reader)  # Membaca header
    for row in reader:
        data.append(row)

# Menyiapkan data yang diperlukan untuk grafik
x = range(1, len(data) + 1)  # Nilai x (misalnya nomor entri)
harga = [float(row[1]) for row in data]  # Nilai harga

# Grafik Batang (Bar Plot)
plt.figure(figsize=(8, 6))
plt.bar(x, harga, color='green', alpha=0.7)
plt.xlabel('Nomor Entri')
plt.ylabel('Harga')
plt.title('Grafik Batang Harga jam')
plt.grid(True)

# Menyimpan gambar grafik batang dengan latar belakang putih
plt.savefig('hasil/grafik_batang_jam.png')

# Menampilkan gambar grafik batang
plt.show()
